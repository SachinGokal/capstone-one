# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as scs
import seaborn as sns
import datetime
import yfinance as yf
import pickle

# %%
    SECTOR_ETF_SYMBOLS = {
        'XLB': 'Materials',
        'XLC': 'Communication Services',
        'XLE': 'Energy',
        'XLF': 'Financials',
        'XLI': 'Industrials',
        'XLK': 'Information Technology',
        'XLP': 'Consumer Staples',
        'XLRE': 'Real Estate',
        'XLU': 'Utilities',
        'XLV': 'Health Care',
        'XLY': 'Consumer Discretionary'
    }

    IMPT_COLUMNS = {'spy_close': 'S&P',
                    'xlb_close': 'Materials',
                    'xlc_close': 'Communication Services',
                    'xle_close': 'Energy',
                    'xlf_close': 'Financials',
                    'xli_close': 'Industrials',
                    'xlk_close': 'Information Technology',
                    'xlp_close': 'Consumer Staples',
                    'xlre_close': 'Real Estate',
                    'xlu_close':  'Utilities',
                    'xlv_close': 'Health Care',
                    'xly_close': 'Consumer Discretionary'}
    symbols = SECTOR_ETF_SYMBOLS.keys()

# %%
    def create_initial_spy_dataframe(start_date="2007-01-01", end_date=datetime.date.today().isoformat()):
      spy_data = yf.download("SPY", start=start_date, end=end_date)
      spy_data = spy_data[['Adj Close']]
      spy_data.rename(columns={'Adj Close': 'spy_close'}, inplace=True)
      return spy_data

# %%
spy_df = create_initial_spy_dataframe()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/sachin/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
spy_df
# Out:
#              spy_close
# Date
# 2007-01-03  107.832581
# 2007-01-04  108.061440
# 2007-01-05  107.199524
# 2007-01-08  107.695328
# 2007-01-09  107.603760
# ...                ...
# 2020-04-01  246.149994
# 2020-04-02  251.830002
# 2020-04-03  248.190002
# 2020-04-06  264.859985
# 2020-04-07  265.130005
#
# [3339 rows x 1 columns]

# %%
 def add_symbol_data_to_dataframe(init_df, start_date="2007-01-01", end_date=datetime.date.today().isoformat()):
      for sym in symbols:
          data = yf.download(sym, start=start_date, end=end_date)
          init_df[f'{sym.lower()}_close'] = data['Adj Close']
      return init_df

# %%
add_symbol_data_to_dataframe(spy_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#              spy_close  xlb_close  xlc_close  xle_close  xlf_close  xli_close  \
# Date
# 2007-01-03  107.832581  25.767790        NaN  40.278873  17.610264  26.685133
# 2007-01-04  108.061440  25.648664        NaN  39.545620  17.553020  26.571518
# 2007-01-05  107.199524  25.477436        NaN  39.809029  17.414692  26.480625
# 2007-01-08  107.695328  25.477436        NaN  39.809029  17.491016  26.579100
# 2007-01-09  107.603760  25.484867        NaN  39.467331  17.462395  26.563938
# ...                ...        ...        ...        ...        ...        ...
# 2020-04-01  246.149994  43.009998  42.480000  27.620001  19.549999  56.349998
# 2020-04-02  251.830002  43.660000  43.020000  30.150000  20.040001  57.099998
# 2020-04-03  248.190002  42.610001  42.150002  29.830000  19.639999  56.340000
# 2020-04-06  264.859985  45.779999  44.930000  31.410000  21.049999  60.240002
# 2020-04-07  265.130005  47.000000  45.259998  32.080002  21.260000  60.099998
#
#             xlk_close  xlp_close  xlre_close  xlu_close  xlv_close   xly_close
# Date
# 2007-01-03  19.024708  18.462629         NaN  22.747271  26.436159   31.657227
# 2007-01-04  19.318270  18.490711         NaN  22.716377  26.736027   31.649019
# 2007-01-05  19.163330  18.357285         NaN  22.308636  26.586088   31.435328
# 2007-01-08  19.220415  18.385380         NaN  22.296274  26.617653   31.484642
# 2007-01-09  19.244881  18.427515         NaN  22.314800  26.586088   31.657227
# ...               ...        ...         ...        ...        ...         ...
# 2020-04-01  76.540001  53.549999   29.120001  52.080002  85.209999   93.699997
# 2020-04-02  78.330002  54.919998   29.549999  53.709999  87.570000   94.050003
# 2020-04-03  77.120003  55.349998   29.299999  51.790001  86.779999   92.410004
# 2020-04-06  83.699997  57.410000   31.420000  55.790001  91.330002  100.099998
# 2020-04-07  82.949997  56.750000   31.430000  55.090000  90.580002  101.589996
#
# [3339 rows x 12 columns]

# %%
    def calculate_betas(init_df, window=10, absvalue=True):
      pct_changes = init_df.pct_change()
      for sym in symbols:
        if absvalue == True:
          pct_changes[f'{sym.lower()}_beta'] = abs(pct_changes.rolling(window).cov().unstack()['spy_close'][f'{sym.lower()}_close'] / pct_changes['spy_close'].rolling(window).var())
        else:
          pct_changes[f'{sym.lower()}_beta'] = pct_changes.rolling(window).cov().unstack()['spy_close'][f'{sym.lower()}_close'] / pct_changes['spy_close'].rolling(window).var()
      return pct_changes

# %%
betas = calculate_betas(spy_df)

# %%
    def get_data_for_a_period(df, start_date, end_date):
      new_df = df.reset_index()
      new_df['Date'] = pd.to_datetime(new_df['Date'])
      mask = (new_df['Date'] > start_date) & (new_df['Date'] <= end_date)
      return new_df.loc[mask]

# %%
    def plot_sector_betas_over_time(betas_df, title):
      fig, axs = plt.subplots(6, 2, sharey=True, figsize=(15, 35))
      plt.tight_layout()
      plt.subplots_adjust(hspace=.6)
      plt.xticks(fontsize=12)
      plt.set_title(title)
      new_df = betas_df.set_index('Date')
      for sym, ax in zip(SECTOR_ETF_SYMBOLS.keys(), axs.flatten()):
        new_df[f'{sym.lower()}_beta'].plot(
            ax=ax, title=SECTOR_ETF_SYMBOLS[sym])
        ax.axhline(y=1, color='r')
        ax.set_ylabel('beta', fontsize=14)
        ax.set_xlabel('date', fontsize=14)
      plt.savefig(title)
      fig.delaxes(axs[-1, -1])

# %%
    def plot_average_betas(df, title):
      fig, ax = plt.subplots(figsize=(12, 8))
      ax.set_title(title, fontsize=18)
      ax.set_ylabel('beta', fontsize=14)
      ax.set_xlabel('sector', fontsize=14)
      df[['sector', 'recent_average_beta', 'historical_average_beta']].plot(kind='bar', x='sector', ax=ax)
      plt.tight_layout()
      plt.savefig(title)

# %%
    def t_test_for_symbol_betas(betas_df, historical_start):
      data = {'symbol': [], 'sector': [], 'p_value': [], 'significant?': [], 'recent_average_beta': [], 'historical_average_beta': [], 'difference': []}
      for sym in symbols:
        if sym == 'XLC' and historical_start < '2018-08-06':
          historical_start = '2018-08-06'
        col = f'{sym.lower()}_beta'
        historical = get_data_for_a_period(betas_df, historical_start, '2020-03-06')[col].values
        recent = get_data_for_a_period(betas_df, '2020-03-06', '2020-04-08')[col].values
        p_value = scs.ttest_ind(historical, recent, equal_var=False)[1]
        data['symbol'].append(sym)
        data['sector'].append(SECTOR_ETF_SYMBOLS[sym])
        data['p_value'].append(p_value)
        data['significant?'].append(p_value < .01)
        data['recent_average_beta'].append(recent.mean())
        data['historical_average_beta'].append(historical.mean())
        data['difference'].append(recent.mean() - historical.mean())
      return pd.DataFrame(data)

# %%
one_month = t_test_for_symbol_betas(betas, '2020-02-06')
one_month.to_clipboard()
one_month
# Out:
#    symbol                  sector       p_value  significant?  \
# 0     XLB               Materials  2.518683e-01         False
# 1     XLC  Communication Services  3.064951e-01         False
# 2     XLE                  Energy  1.398823e-01         False
# 3     XLF              Financials  7.126193e-10          True
# 4     XLI             Industrials  1.665136e-01         False
# 5     XLK  Information Technology  4.278018e-05          True
# 6     XLP        Consumer Staples  3.236326e-03          True
# 7    XLRE             Real Estate  1.300072e-06          True
# 8     XLU               Utilities  4.955123e-07          True
# 9     XLV             Health Care  4.795291e-03          True
# 10    XLY  Consumer Discretionary  7.728943e-02         False
#
#     recent_average_beta  historical_average_beta  difference
# 0              1.049375                 1.116781   -0.067406
# 1              0.893438                 0.839719    0.053719
# 2              1.336598                 1.239690    0.096908
# 3              1.249197                 0.980564    0.268633
# 4              1.110168                 1.041571    0.068597
# 5              1.141133                 1.402461   -0.261328
# 6              0.792140                 0.567676    0.224465
# 7              1.082285                 0.578734    0.503551
# 8              1.065522                 0.471081    0.594442
# 9              0.880450                 1.020170   -0.139720
# 10             0.934157                 0.831628    0.102530

# %%
plot_average_betas(one_month, 'One Month Average Betas')

# %%
plot_sector_betas_over_time(get_data_for_a_period(betas, '2020-02-06', '2020-04-08'), 'one_month_betas.png')

# %%
three_months = t_test_for_symbol_betas(betas, '2019-12-06')
three_months.to_clipboard()
three_months
# Out:
#    symbol                  sector       p_value  significant?  \
# 0     XLB               Materials  8.101359e-01         False
# 1     XLC  Communication Services  6.740666e-02         False
# 2     XLE                  Energy  3.316468e-03          True
# 3     XLF              Financials  3.374506e-04          True
# 4     XLI             Industrials  1.030957e-01         False
# 5     XLK  Information Technology  9.554855e-17          True
# 6     XLP        Consumer Staples  2.836761e-15          True
# 7    XLRE             Real Estate  2.856992e-25          True
# 8     XLU               Utilities  3.951225e-19          True
# 9     XLV             Health Care  5.656541e-01         False
# 10    XLY  Consumer Discretionary  2.113905e-01         False
#
#     recent_average_beta  historical_average_beta  difference
# 0              1.049375                 1.060137   -0.010762
# 1              0.893438                 0.960454   -0.067016
# 2              1.336598                 1.149153    0.187445
# 3              1.249197                 1.125255    0.123941
# 4              1.110168                 1.057148    0.053020
# 5              1.141133                 1.403319   -0.262186
# 6              0.792140                 0.435114    0.357026
# 7              1.082285                 0.462640    0.619645
# 8              1.065522                 0.326670    0.738853
# 9              0.880450                 0.857725    0.022726
# 10             0.934157                 0.896358    0.037800

# %%
plot_sector_betas_over_time(get_data_for_a_period(betas, '2019-12-06', '2020-04-08'), 'three_month_betas.png')

# %%
one_year = t_test_for_symbol_betas(betas, '2019-03-06')
one_year.to_clipboard()
one_year
# Out:
#    symbol                  sector       p_value  significant?  \
# 0     XLB               Materials  8.002802e-01         False
# 1     XLC  Communication Services  1.640884e-09          True
# 2     XLE                  Energy  1.770692e-08          True
# 3     XLF              Financials  3.211318e-12          True
# 4     XLI             Industrials  5.974968e-01         False
# 5     XLK  Information Technology  1.842181e-20          True
# 6     XLP        Consumer Staples  2.582014e-19          True
# 7    XLRE             Real Estate  8.345874e-33          True
# 8     XLU               Utilities  8.783782e-16          True
# 9     XLV             Health Care  4.310804e-01         False
# 10    XLY  Consumer Discretionary  3.518687e-02         False
#
#     recent_average_beta  historical_average_beta  difference
# 0              1.049375                 1.043043    0.006332
# 1              0.893438                 1.054304   -0.160866
# 2              1.336598                 1.071418    0.265180
# 3              1.249197                 1.097799    0.151397
# 4              1.110168                 1.124898   -0.014730
# 5              1.141133                 1.355792   -0.214658
# 6              0.792140                 0.472702    0.319439
# 7              1.082285                 0.499060    0.583225
# 8              1.065522                 0.336788    0.728735
# 9              0.880450                 0.858282    0.022169
# 10             0.934157                 0.973382   -0.039225

# %%
plot_sector_betas_over_time(get_data_for_a_period(betas, '2019-03-06', '2020-04-08'), 'one_year_betas.png')

# %%
five_year = t_test_for_symbol_betas(betas, '2015-03-06')
five_year.to_clipboard()
five_year
# Out:
#    symbol                  sector       p_value  significant?  \
# 0     XLB               Materials  1.451097e-02         False
# 1     XLC  Communication Services  4.661371e-16          True
# 2     XLE                  Energy  6.948749e-11          True
# 3     XLF              Financials  3.628301e-20          True
# 4     XLI             Industrials  2.564435e-01         False
# 5     XLK  Information Technology  4.663482e-27          True
# 6     XLP        Consumer Staples  2.041388e-17          True
# 7    XLRE             Real Estate  2.088272e-29          True
# 8     XLU               Utilities  2.312355e-15          True
# 9     XLV             Health Care  8.069210e-01         False
# 10    XLY  Consumer Discretionary  1.520970e-08          True
#
#     recent_average_beta  historical_average_beta  difference
# 0              1.049375                 1.097853   -0.048479
# 1              0.893438                 1.126784   -0.233346
# 2              1.336598                 1.053410    0.283188
# 3              1.249197                 1.027422    0.221775
# 4              1.110168                 1.081577    0.028591
# 5              1.141133                 1.374609   -0.233476
# 6              0.792140                 0.488035    0.304105
# 7              1.082285                 0.475356    0.606929
# 8              1.065522                 0.328203    0.737320
# 9              0.880450                 0.875095    0.005355
# 10             0.934157                 1.033651   -0.099494

# %%
plot_sector_betas_over_time(get_data_for_a_period(betas, '2015-03-06', '2020-04-08'), 'five_year_betas.png')
